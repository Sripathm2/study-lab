# %% [markdown]
# # ISL Chapter 8: Tree-Based Methods — Exercises
#
# Scaffold for the applied and selected conceptual exercises. The instructions are **paraphrased in my own words** — check the ISLP text for the exact wording and any equations referenced by number. Code cells are left blank for you to fill in.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from ISLP import load_data
from sklearn.tree import DecisionTreeRegressor, DecisionTreeClassifier, plot_tree
from sklearn.ensemble import (RandomForestRegressor, RandomForestClassifier,
                              GradientBoostingRegressor, GradientBoostingClassifier)
from sklearn.model_selection import train_test_split
# BART: from ISLP.bart import BART

# %% [markdown]
# ### Exercise 4 — Trees and partitions (conceptual)
#
# Using Figure 8.14 in the text:
#
# **(a)** Sketch the tree corresponding to the partition in the left panel (box numbers are region means of Y).
# **(b)** Draw the partition corresponding to the tree in the right panel; indicate each region's mean.

# %%
# (a)

# %%
# (b)

# %% [markdown]
# ### Exercise 5 — Combining bootstrapped probabilities (conceptual)
#
# Ten classification trees give P(Class = Red | X) = 0.1, 0.15, 0.2, 0.2, 0.55, 0.6, 0.6, 0.65, 0.7, 0.75. What is the final class under (i) majority vote and (ii) average probability?

# %%
# your code here

# %% [markdown]
# ### Exercise 6 — Regression-tree fitting algorithm (conceptual)
#
# Give a detailed explanation of the algorithm used to fit a regression tree (recursive binary splitting, then cost-complexity pruning).

# %%
# your code here

# %% [markdown]
# ### Exercise 7 — Boston — random forests grid
#
# Plot test error from random forests over a range of `max_features` and `n_estimators` values; describe the results.

# %%
# your code here

# %% [markdown]
# ### Exercise 8 — Carseats — regression trees
#
# Predict `Sales` (quantitative) with trees and ensembles.
#
# **(a)** Split into train/test.
# **(b)** Fit a regression tree; plot and interpret; test MSE.
# **(c)** CV for the optimal tree complexity; does pruning improve test MSE?
# **(d)** Bagging; test MSE; use `feature_importance_`.
# **(e)** Random forests; test MSE; `feature_importance_`; describe the effect of m.
# **(f)** BART; report results.

# %%
# (a)

# %%
# (b)

# %%
# (c)

# %%
# (d)

# %%
# (e)

# %%
# (f)

# %% [markdown]
# ### Exercise 9 — OJ — classification trees
#
# Predict `Purchase` on the `OJ` data.
#
# **(a)** Train = random sample of 800; test = rest.
# **(b)** Fit a tree (`Purchase` ~ others); training error rate.
# **(c)** Plot the tree; how many terminal nodes?
# **(d)** `export_tree()` text summary; interpret one terminal node.
# **(e)** Predict test; confusion matrix; test error rate.
# **(f)** CV on the training set for the optimal tree size.
# **(g)** Plot tree size vs CV classification error.
# **(h)** Which tree size gives the lowest CV error?
# **(i)** Produce the pruned tree at that size (or 5 terminal nodes if CV doesn't prune).
# **(j)** Compare training error: pruned vs unpruned.
# **(k)** Compare test error: pruned vs unpruned.

# %%
# (a)

# %%
# (b)

# %%
# (c)

# %%
# (d)

# %%
# (e)

# %%
# (f)

# %%
# (g)

# %%
# (h)

# %%
# (i)

# %%
# (j)

# %%
# (k)

# %% [markdown]
# ### Exercise 10 — Hitters — boosting
#
# Predict `Salary`.
#
# **(a)** Drop rows with unknown salary; log-transform salary.
# **(b)** Train = first 200 obs; test = rest.
# **(c)** Boosting, 1000 trees, over a range of shrinkage lambda; plot lambda vs training MSE.
# **(d)** Plot lambda vs test MSE.
# **(e)** Compare boosting test MSE to two regression approaches from ch. 3 or 6.
# **(f)** Most important predictors in the boosted model.
# **(g)** Bagging; test MSE.

# %%
# (a)

# %%
# (b)

# %%
# (c)

# %%
# (d)

# %%
# (e)

# %%
# (f)

# %%
# (g)

# %% [markdown]
# ### Exercise 11 — Caravan — boosting
#
# Predict `Purchase`.
#
# **(a)** Train = first 1000; test = rest.
# **(b)** Boosting, 1000 trees, shrinkage 0.01; most important predictors?
# **(c)** Predict test; classify buy if P(purchase) > 20%; confusion matrix; what fraction predicted to buy actually do? Compare to KNN / logistic.

# %%
# (a)

# %%
# (b)

# %%
# (c)

# %% [markdown]
# ### Exercise 12 — Ensembles on a data set of your choice
#
# Apply boosting, bagging, random forests, and BART to a data set of your choice (fit on train, evaluate on test). Compare to simple linear/logistic regression. Which performs best?

# %%
# your code here
