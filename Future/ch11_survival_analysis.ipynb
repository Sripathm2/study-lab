# %% [markdown]
# # ISL Chapter 11: Survival Analysis — Exercises
#
# Scaffold for the applied and selected conceptual exercises. The instructions are **paraphrased in my own words** — check the ISLP text for the exact wording and any equations referenced by number. Code cells are left blank for you to fill in.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from ISLP import load_data
from lifelines import KaplanMeierFitter, CoxPHFitter
from lifelines.statistics import logrank_test

# %% [markdown]
# ### Exercise 10 — Brain tumor data
#
# Survival analysis on the `BrainCancer` data (ISLP).
#
# **(a)** Kaplan-Meier survival curve with +/-1 SE bands (`KaplanMeierFitter`, lifelines).
# **(b)** Bootstrap: draw samples of size n=88 from the (y_i, delta_i) pairs, compute the KM curve, repeat B=200 times; estimate the SE of the KM curve at each timepoint; compare to (a).
# **(c)** Cox proportional-hazards model with all predictors; summarize the main findings.
# **(d)** Stratify by `ki` (group the single ki=40 obs with ki=60); plot KM curves per stratum, adjusted for the other predictors.

# %%
# (a)

# %%
# (b)

# %%
# (c)

# %%
# (d)

# %% [markdown]
# ### Exercise 11 — Table 11.4 data
#
# Use the data in the book's Table 11.4.
#
# **(a)** Two groups (X < 2 vs X >= 2); plot and label the KM curves; by eye, do the curves differ?
# **(b)** Cox PH with the group indicator as covariate; estimated coefficient; interpret in terms of the hazard; is it non-zero?
# **(c)** Log-rank test for a difference between the groups; compare its p-value to the score-statistic p-value from the Cox model in (b).

# %%
# (a)

# %%
# (b)

# %%
# (c)
