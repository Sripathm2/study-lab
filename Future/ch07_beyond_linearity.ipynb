# %% [markdown]
# # ISL Chapter 7: Beyond Linearity — Exercises
#
# Scaffold for the applied and selected conceptual exercises. The instructions are **paraphrased in my own words** — check the ISLP text for the exact wording and any equations referenced by number. Code cells are left blank for you to fill in.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import statsmodels.api as sm
from ISLP import load_data
from ISLP.models import ModelSpec as MS, summarize, poly, bs, ns
# GAMs in ISLP use pygam; import as needed

# %% [markdown]
# ### Exercise 6 — Wage — polynomial and step functions
#
# Analyze `Wage`.
#
# **(a)** Polynomial regression `wage` ~ `age`; CV to select degree d; compare to ANOVA-based hypothesis testing; plot the fit.
# **(b)** Step function `wage` ~ `age`; CV to choose the number of cuts; plot the fit.

# %%
# (a)

# %%
# (b)

# %% [markdown]
# ### Exercise 7 — Wage — other predictors
#
# Explore other `Wage` features (e.g. `maritl`, `jobclass`) with flexible/non-linear fits; plot results and summarize findings.

# %%
# your code here

# %% [markdown]
# ### Exercise 8 — Auto — non-linear models
#
# Fit some non-linear models to `Auto`; is there evidence of non-linear relationships? Make informative plots.

# %%
# your code here

# %% [markdown]
# ### Exercise 9 — Boston — dis and nox
#
# Predict `nox` from `dis`.
#
# **(a)** Cubic polynomial `nox` ~ `dis` (use `poly` from `ISLP.models`); report output; plot fit.
# **(b)** Polynomial fits for degrees 1-10; report the associated RSS.
# **(c)** CV (or another approach) to select the optimal degree; explain.
# **(d)** Regression spline (`bs`) with 4 degrees of freedom; how did you choose the knots? Plot the fit.
# **(e)** Spline fits over a range of df; plot and report RSS.
# **(f)** CV to select the best df; describe.

# %%
# (a)

# %%
# (b)

# %%
# (c)

# %%
# (d)

# %%
# (e)

# %%
# (f)

# %% [markdown]
# ### Exercise 10 — College — GAM
#
# Predict `Outstate` on `College`.
#
# **(a)** Split into train/test; forward stepwise selection on train to pick a subset of predictors.
# **(b)** Fit a GAM on the selected features; plot; explain findings.
# **(c)** Evaluate on the test set; explain.
# **(d)** For which variables is there evidence of a non-linear relationship?

# %%
# (a)

# %%
# (b)

# %%
# (c)

# %%
# (d)

# %% [markdown]
# ### Exercise 11 — Backfitting for multiple regression
#
# Explore backfitting (updating one coefficient at a time via simple regressions).
#
# **(a)** Generate Y and two predictors X1, X2 (n=100).
# **(b)** Write `simple_reg(outcome, feature)` returning the estimated intercept and slope.
# **(c)** Initialize `beta1` to any value.
# **(d)** Holding beta1 fixed, fit (Y - beta1*X1) ~ X2 -> store beta0, beta2.
# **(e)** Holding beta2 fixed, fit (Y - beta2*X2) ~ X1 -> overwrite beta0, beta1.
# **(f)** Loop (d)-(e) 1000 times; record beta0, beta1, beta2 each iteration; plot the three sequences.
# **(g)** Compare to a direct multiple regression of Y on X1, X2; overlay those coefficients (`axline`).
# **(h)** How many backfitting iterations gave a good approximation?

# %%
# (a)

# %%
# (b)

# %%
# (c)

# %%
# (d)

# %%
# (e)

# %%
# (f)

# %%
# (g)

# %%
# (h)

# %% [markdown]
# ### Exercise 12 — Backfitting with p = 100
#
# In a toy example with p=100, show that repeated simple regressions (backfitting) approximate the multiple-regression coefficients. How many iterations are needed? Plot to justify.

# %%
# your code here
