# %% [markdown]
# # ISL Chapter 9: Support Vector Machines — Exercises
#
# Scaffold for the applied and selected conceptual exercises. The instructions are **paraphrased in my own words** — check the ISLP text for the exact wording and any equations referenced by number. Code cells are left blank for you to fill in.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from ISLP import load_data
from sklearn.svm import SVC
from sklearn.model_selection import train_test_split, GridSearchCV
# lab helper: from ISLP.svm import plot as plot_svm

# %% [markdown]
# ### Exercise 3 — Maximal margin classifier — toy data (conceptual)
#
# Seven observations, p=2, with class labels (see the table in the book: obs 1-4 Red, 5-7 Blue).
#
# **(a)** Sketch the observations.
# **(b)** Sketch the optimal separating hyperplane and give its equation.
# **(c)** State the classification rule and give beta_0, beta_1, beta_2.
# **(d)** Indicate the margin on your sketch.
# **(e)** Indicate the support vectors.
# **(f)** Argue a slight move of the 7th observation wouldn't change the hyperplane.
# **(g)** Sketch a non-optimal separating hyperplane and give its equation.
# **(h)** Add an observation so the two classes are no longer linearly separable.

# %%
# (a)

# %%
# (b)

# %%
# (c)

# %%
# (d)

# %%
# (e)

# %%
# (f)

# %%
# (g)

# %%
# (h)

# %% [markdown]
# ### Exercise 4 — Simulated — non-linear separation
#
# Generate 100 obs with two features and a visible but non-linear class boundary. Show a polynomial-kernel (degree > 1) or radial SVM beats a linear support-vector classifier on training data. Which is best on test data? Plot and report training/test error rates.

# %%
# your code here

# %% [markdown]
# ### Exercise 5 — Logistic regression with non-linear transforms
#
# Get a non-linear boundary from logistic regression via non-linear feature transforms.
#
# **(a)** Generate n=500, p=2 with a quadratic boundary:
# **(b)** Plot the observations colored by class (X1 on x-axis, X2 on y-axis).
# **(c)** Logistic regression with X1, X2.
# **(d)** Predict on training data and plot by predicted class — boundary should be linear.
# **(e)** Logistic regression with non-linear functions (X1^2, X1*X2, log(X2), ...).
# **(f)** Predict and plot — boundary should be clearly non-linear (repeat (a)-(e) until it is).
# **(g)** Support vector classifier with X1, X2; predict and plot.
# **(h)** SVM with a non-linear kernel; predict and plot.
# **(i)** Comment on your results.

# %%
# (a)
rng = np.random.default_rng(5)
x1 = rng.uniform(size=500) - 0.5
x2 = rng.uniform(size=500) - 0.5
y = x1**2 - x2**2 > 0

# %%
# (b)

# %%
# (c)

# %%
# (d)

# %%
# (e)

# %%
# (f)

# %%
# (g)

# %%
# (h)

# %%
# (i)

# %% [markdown]
# ### Exercise 6 — Barely separable — the role of C
#
# Investigate the claim that a small C (allowing a few misclassifications) can beat a huge C on test data.
#
# **(a)** Generate two-class p=2 data that is just barely linearly separable.
# **(b)** CV error for a range of C; how many training obs are misclassified for each C? Relate to the CV errors.
# **(c)** Generate a test set; test error for each C. Which C is best on test vs train vs CV?
# **(d)** Discuss.

# %%
# (a)

# %%
# (b)

# %%
# (c)

# %%
# (d)

# %% [markdown]
# ### Exercise 7 — Auto — SVMs for high/low mpg
#
# Predict whether a car has above/below-median gas mileage.
#
# **(a)** Create the binary response (1 if mpg above median, else 0).
# **(b)** Support vector classifier for various C; report CV errors; comment (drop the mpg variable itself).
# **(c)** SVMs with radial and polynomial kernels, various gamma / degree / C; comment.
# **(d)** Make plots to back up (b) and (c) (lab's `plot_svm`; use `features` kwarg when p > 2).

# %%
# (a)

# %%
# (b)

# %%
# (c)

# %%
# (d)

# %% [markdown]
# ### Exercise 8 — OJ — SVMs
#
# Predict `Purchase` on `OJ`.
#
# **(a)** Train = 800; test = rest.
# **(b)** Support vector classifier, C = 0.01, `Purchase` ~ others; how many support points?
# **(c)** Training and test error rates.
# **(d)** CV to select C in [0.01, 10].
# **(e)** Training and test error with the selected C.
# **(f)** Repeat (b)-(e) with a radial kernel (default gamma).
# **(g)** Repeat (b)-(e) with a polynomial kernel, degree = 2.
# **(h)** Which approach is best overall?

# %%
# (a)

# %%
# (b)

# %%
# (c)

# %%
# (d)

# %%
# (e)

# %%
# (f)

# %%
# (g)

# %%
# (h)
