# %% [markdown]
# # ISL Chapter 4: Classification — Exercises
#
# Scaffold for the applied and selected conceptual exercises. The instructions are **paraphrased in my own words** — check the ISLP text for the exact wording and any equations referenced by number. Code cells are left blank for you to fill in.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import statsmodels.api as sm
from ISLP import load_data
from ISLP.models import ModelSpec as MS, summarize
from sklearn.discriminant_analysis import (LinearDiscriminantAnalysis as LDA,
                                           QuadraticDiscriminantAnalysis as QDA)
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier

# %% [markdown]
# ### Exercise 10 — LDA discriminant, p = 1 (conceptual)
#
# The book's Eq. 4.32 gives log[Pr(Y=k|x)/Pr(Y=K|x)] for p>1. Redo the calculation for the p=1 case (scalar means and variance) and give a_k and b_kj in terms of pi_k, pi_K, mu_k, mu_K, and sigma^2.

# %%
# your code here

# %% [markdown]
# ### Exercise 11 — QDA discriminant forms (conceptual)
#
# Work out the detailed forms of a_k, b_kj, and b_kjl in Eq. 4.33, in terms of pi_k, pi_K, mu_k, mu_K, Sigma_k, and Sigma_K.

# %%
# your code here

# %% [markdown]
# ### Exercise 12 — Logistic vs softmax coding (conceptual)
#
# Compare a two-class logistic model with a friend's softmax formulation for classifying apples vs oranges.
#
# **(a)** Log-odds of orange vs apple in your (logistic) model.
# **(b)** Log-odds of orange vs apple in the friend's softmax model.
# **(c)** If your beta-hat_0 = 2, beta-hat_1 = -1, what are the friend's coefficient estimates? Be as specific as possible.
# **(d)** Given the friend's softmax coefficients on another data set, what are your logistic coefficients?
# **(e)** On 2000 test observations, what fraction of predictions should agree between the two models? Explain.

# %%
# (a)

# %%
# (b)

# %%
# (c)

# %%
# (d)

# %%
# (e)

# %% [markdown]
# ### Exercise 13 — Weekly
#
# Use the `Weekly` data (1089 weekly returns, 1990-2010).
#
# **(a)** Numerical and graphical summaries; any patterns?
# **(b)** Logistic regression `Direction` ~ Lag1..Lag5 + Volume (full data); which predictors are significant?
# **(c)** Confusion matrix and overall fraction correct; interpret the types of mistakes.
# **(d)** Refit logistic with train = 1990-2008, `Lag2` only; confusion matrix and accuracy on the 2009-2010 hold-out.
# **(e)** Repeat (d) with LDA.
# **(f)** Repeat (d) with QDA.
# **(g)** Repeat (d) with KNN, K = 1.
# **(h)** Repeat (d) with naive Bayes.
# **(i)** Which method gives the best hold-out results?
# **(j)** Experiment with predictor sets, transformations, interactions, and K; report the best combination and its confusion matrix.

# %%
# (a)

# %%
# (b)

# %%
# (c)

# %%
# (d)

# %%
# (e)

# %%
# (f)

# %%
# (g)

# %%
# (h)

# %%
# (i)

# %%
# (j)

# %% [markdown]
# ### Exercise 14 — Auto — predict high/low mpg
#
# Predict whether a car gets high or low gas mileage.
#
# **(a)** Create binary `mpg01` = 1 if `mpg` is above its median, else 0; add it to the data frame.
# **(b)** Explore graphically which features associate with `mpg01` (scatterplots, boxplots); describe.
# **(c)** Split into train and test sets.
# **(d)** LDA on the selected features; test error.
# **(e)** QDA; test error.
# **(f)** Logistic regression; test error.
# **(g)** Naive Bayes; test error.
# **(h)** KNN for several K; test errors; which K is best?

# %%
# (a)
# after computing mpg01 (1 if mpg above its median, else 0):
Auto['mpg01'] = mpg01

# %%
# (b)

# %%
# (c)

# %%
# (d)

# %%
# (e)

# %%
# (f)

# %%
# (g)

# %%
# (h)

# %% [markdown]
# ### Exercise 15 — Writing functions
#
# Practice writing functions.
#
# **(a)** `Power()` that prints 2**3.
# **(b)** `Power2(x, a)` that prints x**a (e.g. `Power2(3, 8)` -> 6561).
# **(c)** Use `Power2` to compute 10**3, 8**17, and 131**3.
# **(d)** `Power3(x, a)` that *returns* x**a as an object.
# **(e)** Using `Power3`, plot f(x) = x**2 for x = 1..10; label axes and title; consider log scales via `ax.set_xscale`/`ax.set_yscale`.
# **(f)** `PlotPower(x_values, a)` that plots x against x**a, e.g. `PlotPower(np.arange(1, 11), 3)`.

# %%
# (a)

# %%
# (b)

# %%
# (c)

# %%
# (d)

# %%
# (e)

# %%
# (f)

# %% [markdown]
# ### Exercise 16 — Boston — classify crime above/below median
#
# Fit logistic regression, LDA, naive Bayes, and KNN to predict whether a suburb's crime rate is above or below the median, using various predictor subsets. Create the binary response yourself; describe your findings.

# %%
# your code here
