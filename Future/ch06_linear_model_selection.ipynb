# %% [markdown]
# # ISL Chapter 6: Linear Model Selection — Exercises
#
# Scaffold for the applied and selected conceptual exercises. The instructions are **paraphrased in my own words** — check the ISLP text for the exact wording and any equations referenced by number. Code cells are left blank for you to fill in.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from ISLP import load_data
from ISLP.models import ModelSpec as MS
import sklearn.linear_model as skl
from sklearn.decomposition import PCA
from sklearn.cross_decomposition import PLSRegression
from sklearn.model_selection import KFold, train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
# reminder: on scikit-learn >= 1.7 pass alphas=100 (not n_alphas=100)

# %% [markdown]
# ### Exercise 8 — Simulated — stepwise selection and the lasso
#
# Generate data, then run forward/backward stepwise and the lasso.
#
# **(a)** Create a predictor X (n=100) and a noise vector eps with the RNG's `normal` method.
# **(b)** Y = beta_0 + beta_1 X + beta_2 X^2 + beta_3 X^3 + eps (constants of your choice).
# **(c)** Forward stepwise selection using predictors X, X^2, ..., X^10; best model by Cp; report its coefficients.
# **(d)** Backward stepwise selection; compare to (c).
# **(e)** Lasso on X..X^10; CV to pick lambda; plot CV error vs lambda; report coefficients; discuss.
# **(f)** Now Y = beta_0 + beta_7 X^7 + eps; run forward stepwise and the lasso; discuss.

# %%
# (a)
rng = np.random.default_rng(1)

# %%
# (b)

# %%
# (c)

# %%
# (d)

# %%
# (e)

# %%
# (f)

# %% [markdown]
# ### Exercise 9 — College — predict number of applications
#
# Predict `Apps` from the other `College` variables.
#
# **(a)** Split into train/test.
# **(b)** Least squares on the training set; report test error.
# **(c)** Ridge with lambda chosen by CV; test error.
# **(d)** Lasso with lambda chosen by CV; test error and number of non-zero coefficients.
# **(e)** PCR with M chosen by CV; test error and M.
# **(f)** PLS with M chosen by CV; test error and M.
# **(g)** Comment: how accurately can you predict `Apps`? Much difference among the five approaches?

# %%
# (a)

# %%
# (b)

# %%
# (c)

# %%
# (d)

# %%
# (e)

# %%
# (f)

# %%
# (g)

# %% [markdown]
# ### Exercise 10 — Simulated — p = 20 features
#
# Explore how test error behaves as model size grows.
#
# **(a)** Generate p=20, n=1000, Y = X beta + eps with some beta_j exactly 0.
# **(b)** Split: 100 train, 900 test.
# **(c)** Best subset selection on train; plot training MSE for the best model of each size.
# **(d)** Plot test MSE for the best model of each size.
# **(e)** Which model size minimizes test MSE? (If it's the intercept-only or full model, tweak the data generation.)
# **(f)** Compare the min-test-MSE model to the true model; comment on the coefficients.
# **(g)** Plot sqrt(sum_j (beta_j - beta-hat^r_j)^2) vs r; compare to the test-MSE plot from (d).

# %%
# (a)

# %%
# (b)

# %%
# (c)

# %%
# (d)

# %%
# (e)

# %%
# (f)

# %%
# (g)

# %% [markdown]
# ### Exercise 11 — Boston — predict crime rate
#
# Predict per-capita crime rate.
#
# **(a)** Try best subset, lasso, ridge, and PCR; present and discuss.
# **(b)** Propose a model (or set); justify using validation/CV error, not training error.
# **(c)** Does your chosen model use all features? Why or why not?

# %%
# (a)

# %%
# (b)

# %%
# (c)
