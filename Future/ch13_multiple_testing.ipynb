# %% [markdown]
# # ISL Chapter 13: Multiple Testing — Exercises
#
# Scaffold for the applied and selected conceptual exercises. The instructions are **paraphrased in my own words** — check the ISLP text for the exact wording and any equations referenced by number. Code cells are left blank for you to fill in.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import statsmodels.api as sm
from scipy import stats
from statsmodels.stats.multitest import multipletests
from ISLP import load_data

# %% [markdown]
# ### Exercise 5 — Bonferroni vs Holm examples (conceptual)
#
# Construct p-value examples.
#
# **(a)** Five p-values for which Bonferroni and Holm each reject exactly one null at FWER 0.1.
# **(b)** Five p-values for which Bonferroni rejects one but Holm rejects more than one at FWER 0.1.

# %%
# (a)

# %%
# (b)

# %% [markdown]
# ### Exercise 6 — Reading Figure 13.3 panels (conceptual)
#
# For each of the three panels in the book's Figure 13.3:
#
# **(a)** Counts of false pos / false neg / true pos / true neg / Type I / Type II errors from Bonferroni at FWER alpha = 0.05.
# **(b)** Same counts from Holm at alpha = 0.05.
# **(c)** False discovery proportion under Bonferroni at alpha = 0.05.
# **(d)** False discovery proportion under Holm at alpha = 0.05.
# **(e)** How do (a) and (c) change at alpha = 0.001?

# %%
# (a)

# %%
# (b)

# %%
# (c)

# %%
# (d)

# %%
# (e)

# %% [markdown]
# ### Exercise 7 — Carseats — multiple testing
#
# For each quantitative predictor besides `Sales`, fit a simple regression `Sales ~ X` and collect the coefficient p-values.
#
# **(a)** Report the beta_1 p-value from each simple model.
# **(b)** Control Type I error at 0.05 for these p-values; which nulls do you reject?
# **(c)** Control the FWER at 0.05; which do you reject?
# **(d)** Control the FDR at 0.2; which do you reject?

# %%
# (a)

# %%
# (b)

# %%
# (c)

# %%
# (d)

# %% [markdown]
# ### Exercise 8 — Simulated fund managers
#
# Simulate m=100 managers with n=20 monthly returns each (all true nulls: population mean 0).
#
# **(a)** One-sample t-test per manager; histogram of the 100 p-values.
# **(b)** Control Type I error at 0.05 per test; how many nulls rejected?
# **(c)** Control the FWER at 0.05; how many rejected?
# **(d)** Control the FDR at 0.05; how many rejected?
# **(e)** Cherry-pick the 10 best-performing managers; control FWER (and FDR) at 0.05 for just those 10; how many rejected?
# **(f)** Explain why the analysis in (e) is misleading.

# %%
# (a)
rng = np.random.default_rng(1)
n, m = 20, 100
X = rng.normal(size=(n, m))

# %%
# (b)

# %%
# (c)

# %%
# (d)

# %%
# (e)

# %%
# (f)
