# %% [markdown]
# # ISL Chapter 10: Deep Learning — Exercises
#
# Scaffold for the applied and selected conceptual exercises. The instructions are **paraphrased in my own words** — check the ISLP text for the exact wording and any equations referenced by number. Code cells are left blank for you to fill in.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from ISLP import load_data
# ISLP ch.10 uses pytorch; import torch and the ISLP torch helpers as needed:
# import torch
# from torch import nn

# %% [markdown]
# ### Exercise 4 — CNN as a constrained feed-forward net (conceptual)
#
# About a small convolutional model (see the book's figure/setup).
#
# **(b)** How many parameters are in the model?
# **(c)** Explain how it can be viewed as an ordinary feed-forward net on the individual pixels, with constraints on the hidden-unit weights. What are the constraints?
# **(d)** With no constraints, how many weights would that feed-forward net have?

# %%
# (b)

# %%
# (c)

# %%
# (d)

# %% [markdown]
# ### Exercise 5 — MAE vs test R^2 ordering (conceptual)
#
# In the book's Table 10.2 the ranking of three methods by mean absolute error differs from the ranking by test-set R^2. How can that happen?

# %%
# your code here

# %% [markdown]
# ### Exercise 6 — Gradient descent on R(beta) = sin(beta) + beta/10
#
# Hand-run gradient descent on a simple non-convex function.
#
# **(a)** Plot R(beta) over beta in [-6, 6].
# **(b)** Give the derivative R'(beta).
# **(c)** From beta_0 = 2.3, run gradient descent with learning rate rho = 0.1 to a local min; show the iterates beta_0, beta_1, ... on the plot and the final answer.
# **(d)** Repeat from beta_0 = 1.4.

# %%
# (a)

# %%
# (b)

# %%
# (c)

# %%
# (d)

# %% [markdown]
# ### Exercise 7 — Default — neural network
#
# Fit a neural net to `Default`: one hidden layer, 10 units, dropout. Compare classification performance to linear logistic regression (see Labs 10.9.1-10.9.2).

# %%
# your code here

# %% [markdown]
# ### Exercise 8 — Pretrained CNN on your own photos
#
# Pick 10 personal animal photos (crop if needed). Use a pretrained image-classification CNN (as in Lab 10.9.4) to predict each image's class; report the top-5 predicted classes and probabilities. (Needs your own image files.)

# %%
# your code here

# %% [markdown]
# ### Exercise 9 — NYSE — lag-5 AR model
#
# Fit a lag-5 autoregressive model to the `NYSE` data (as in Lab 10.9.6). Refit adding a 12-level month factor. Does the month factor improve performance?

# %%
# your code here

# %% [markdown]
# ### Exercise 10 — NYSE — linear AR by flattening
#
# Fit a linear AR model to `NYSE` by 'flattening' the short RNN sequences (instead of `LinearRegression` on the lag matrix directly). Compare test R^2 to the lab's linear AR model; note advantages/disadvantages of each approach.

# %%
# your code here

# %% [markdown]
# ### Exercise 11 — NYSE — non-linear AR by flattening
#
# Repeat the previous exercise but fit a non-linear AR model by flattening the RNN sequences.

# %%
# your code here

# %% [markdown]
# ### Exercise 12 — NYSE — RNN with day_of_week
#
# Modify the Section 10.9.6 RNN to include `day_of_week`; fit it and compute the test R^2.

# %%
# your code here

# %% [markdown]
# ### Exercise 13 — IMDb — network width and dropout
#
# Repeat the Lab 10.9.5 IMDb analysis (two hidden layers). Explore 16 vs 32 vs 64 units per layer, with and without 30% dropout.

# %%
# your code here
