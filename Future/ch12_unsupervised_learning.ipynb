# %% [markdown]
# # ISL Chapter 12: Unsupervised Learning — Exercises
#
# Scaffold for the applied and selected conceptual exercises. The instructions are **paraphrased in my own words** — check the ISLP text for the exact wording and any equations referenced by number. Code cells are left blank for you to fill in.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from ISLP import load_data
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
from scipy.cluster.hierarchy import linkage, dendrogram, cut_tree
from sklearn.metrics import pairwise_distances

# %% [markdown]
# ### Exercise 6 — PCA loadings via least squares (conceptual)
#
# Given the M principal-component score vectors, explain (using the PCA optimization) that each of the first M loading vectors can be obtained by p separate least-squares regressions (scores as predictors, one feature as the response).

# %%
# your code here

# %% [markdown]
# ### Exercise 7 — USArrests — correlation vs Euclidean distance
#
# Show that after centering/scaling each observation, 1 - r_ij is proportional to the squared Euclidean distance between observations i and j (use `pairwise_distances` and `np.corrcoef`).

# %%
# your code here

# %% [markdown]
# ### Exercise 8 — USArrests — PVE two ways
#
# Compute the proportion of variance explained (PVE).
#
# **(a)** From the fitted `PCA` estimator's `explained_variance_ratio_`.
# **(b)** Directly from Eq. 12.10, using the loadings (`components_`). (Center/scale the same way in both parts so the answers match.)

# %%
# (a)

# %%
# (b)

# %% [markdown]
# ### Exercise 9 — USArrests — hierarchical clustering
#
# Cluster the states.
#
# **(a)** Complete linkage, Euclidean distance; cluster the states.
# **(b)** Cut the dendrogram into 3 clusters; which states go where?
# **(c)** Repeat after scaling variables to sd 1.
# **(d)** What effect does scaling have? Should variables be scaled first? Justify.

# %%
# (a)

# %%
# (b)

# %%
# (c)

# %%
# (d)

# %% [markdown]
# ### Exercise 10 — Simulated — PCA and K-means
#
# Generate labeled data and cluster it.
#
# **(a)** 3 classes x 20 obs (60 total), 50 variables, with a mean shift per class.
# **(b)** PCA; plot the first two score vectors colored by class. (If classes overlap, revise (a).)
# **(c)** K-means with K=3; compare clusters to the true labels (`pd.crosstab`; remember cluster labels are arbitrary).
# **(d)** K-means with K=2; describe.
# **(e)** K-means with K=4; describe.
# **(f)** K-means with K=3 on the first two score vectors (the 60x2 matrix); comment.
# **(g)** K-means with K=3 after `StandardScaler`; compare to (b).

# %%
# (a)

# %%
# (b)

# %%
# (c)

# %%
# (d)

# %%
# (e)

# %%
# (f)

# %%
# (g)

# %% [markdown]
# ### Exercise 11 — Matrix completion (Algorithm 12.1)
#
# Write a matrix-completion function (track relative error and iteration count; stop on small error or max iterations; option to print progress). Test on `Boston` (standardize first); randomly leave out 5%-30% (nested) in steps of 5%; run with M=1..8; plot approximation error vs missing fraction and M, averaged over 10 repetitions.

# %%
# your code here

# %% [markdown]
# ### Exercise 12 — Matrix completion via PCA()
#
# Reimplement Algorithm 12.1 using the `PCA` estimator instead of `np.linalg.svd`.

# %%
# your code here

# %% [markdown]
# ### Exercise 13 — Gene expression (Ch12Ex13.csv)
#
# 40 tissue samples x 1000 genes (first 20 healthy, next 20 diseased).
#
# **(a)** Load with `pd.read_csv(..., header=None)`.
# **(b)** Hierarchical clustering with correlation-based distance; plot the dendrogram. Do the samples split into the two groups? Does it depend on the linkage?
# **(c)** Suggest and apply a way to find which genes differ most across the two groups.

# %%
# (a)

# %%
# (b)

# %%
# (c)
