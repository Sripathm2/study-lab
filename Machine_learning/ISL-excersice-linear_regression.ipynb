# %% [markdown]
# # ISL Chapter 3: Linear Regression — Exercises
#
# Scaffold for the applied and selected conceptual exercises. The instructions are **paraphrased in my own words** — check the ISLP text for the exact wording and any equations referenced by number. Code cells are left blank for you to fill in.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import statsmodels.api as sm
from ISLP import load_data
from ISLP.models import ModelSpec as MS, summarize, poly

# %% [markdown]
# ### Exercise 6 — Least-squares line passes through the means (conceptual)
#
# Using the simple-regression coefficient formulas, argue that the least-squares line always passes through the point (x̄, ȳ). (Written/proof answer — use the cell for any numerical check.)

# %%
# your code here

# %% [markdown]
# ### Exercise 7 — R^2 = correlation^2 in simple regression (conceptual)
#
# Prove that for simple linear regression of Y on X, the R^2 statistic equals the squared correlation between X and Y. You may assume x̄ = ȳ = 0.

# %%
# your code here

# %% [markdown]
# ### Exercise 8 — Auto — simple linear regression
#
# Simple linear regression on `Auto`.
#
# **(a)** `sm.OLS`: `mpg` ~ `horsepower`; print with `summarize`. Comment on: (i) is there a relationship? (ii) how strong? (iii) positive or negative? (iv) predicted `mpg` at `horsepower = 98`, plus its 95% confidence and prediction intervals.
# **(b)** Plot response vs predictor and overlay the least-squares line (`ax.axline` or the lab's `abline`).
# **(c)** Produce diagnostic plots; comment on any problems with the fit.

# %%
# (a)

# %%
# (b)

# %%
# (c)

# %% [markdown]
# ### Exercise 9 — Auto — multiple linear regression
#
# Multiple linear regression on `Auto`.
#
# **(a)** Scatterplot matrix of all variables.
# **(b)** Correlation matrix with `DataFrame.corr()`.
# **(c)** `sm.OLS`: `mpg` ~ all predictors except `name`; `summarize`. Comment: (i) overall relationship (use `anova_lm`), (ii) which predictors are significant, (iii) what the `year` coefficient suggests.
# **(d)** Diagnostic plots; do residual plots flag large outliers? Does the leverage plot flag high-leverage points?
# **(e)** Fit some interaction models; any interactions significant?
# **(f)** Try transformations of the variables (log(X), sqrt(X), X^2); comment.

# %%
# (a)

# %%
# (b)

# %%
# (c)

# %%
# (d)

# %%
# (e)

# %%
# (f)

# %% [markdown]
# ### Exercise 10 — Carseats
#
# Regression on `Carseats`.
#
# **(a)** Fit `Sales` ~ `Price` + `Urban` + `US`.
# **(b)** Interpret each coefficient — careful, some predictors are qualitative.
# **(c)** Write out the model in equation form, handling the qualitative variables properly.
# **(d)** For which predictors can you reject H0: beta_j = 0?
# **(e)** Fit a smaller model using only the predictors with evidence of association.
# **(f)** How well do the models in (a) and (e) fit?
# **(g)** 95% confidence intervals for the coefficient(s) in the model from (e).
# **(h)** Evidence of outliers or high-leverage points in the model from (e)?

# %%
# (a)

# %%
# (b)

# %%
# (c)

# %%
# (d)

# %%
# (e)

# %%
# (f)

# %%
# (g)

# %%
# (h)

# %% [markdown]
# ### Exercise 11 — t-statistic for regression without an intercept
#
# Investigate the t-statistic for H0: beta = 0 in simple regression without an intercept. Starter data:
#
# **(a)** Regress `y` onto `x` without an intercept; report beta-hat, its SE, the t-statistic and p-value. (Pass `intercept=False` to `ModelSpec`.) Comment.
# **(b)** Regress `x` onto `y` without an intercept; report the same quantities; comment.
# **(c)** What is the relationship between (a) and (b)?
# **(d)** Show algebraically (and confirm numerically) the given closed form for the t-statistic.
# **(e)** Argue the t-statistic for y-on-x equals the t-statistic for x-on-y.
# **(f)** Show that with an intercept, the t-statistic for H0: beta_1 = 0 is the same both directions.

# %%
# (a)
rng = np.random.default_rng(1)
x = rng.normal(size=100)
y = 2 * x + rng.normal(size=100)

# %%
# (b)

# %%
# (c)

# %%
# (d)

# %%
# (e)

# %%
# (f)

# %% [markdown]
# ### Exercise 12 — Coefficients for regression without an intercept
#
# Simple regression without an intercept.
#
# **(a)** Under what condition is beta-hat for X-on-Y equal to beta-hat for Y-on-X?
# **(b)** Generate an n=100 example where the two coefficient estimates differ.
# **(c)** Generate an n=100 example where they are equal.

# %%
# (a)

# %%
# (b)

# %%
# (c)

# %% [markdown]
# ### Exercise 13 — Simulated data (seed 1)
#
# Create simulated data and fit simple regressions. Set the default RNG seed to 1 before starting.
#
# **(a)** Create `x`: 100 draws from N(0, 1).
# **(b)** Create `eps`: 100 draws from N(0, 0.25) (variance 0.25).
# **(c)** Form `y = -1 + 0.5*x + eps`. What is len(y)? What are beta_0 and beta_1?
# **(d)** Scatterplot of x vs y; comment.
# **(e)** Least-squares fit y ~ x; compare beta-hat_0, beta-hat_1 to the true values.
# **(f)** Overlay the least-squares line and the population line (different color) with a legend.
# **(g)** Fit a polynomial model y ~ x + x^2; evidence the quadratic term helps?
# **(h)** Repeat (a)-(f) with less noise (smaller error variance); describe.
# **(i)** Repeat (a)-(f) with more noise; describe.
# **(j)** Confidence intervals for beta_0, beta_1 across the original, noisier, and less-noisy data sets; comment.

# %%
# (a)
rng = np.random.default_rng(1)

# %%
# (b)

# %%
# (c)

# %%
# (d)

# %%
# (e)

# %%
# (f)

# %%
# (g)

# %%
# (h)

# %%
# (i)

# %%
# (j)

# %% [markdown]
# ### Exercise 14 — Collinearity
#
# The collinearity problem.
#
# **(a)** Run the commands below. Write out the linear model form; what are the true regression coefficients?
# **(b)** Correlation between x1 and x2; scatterplot.
# **(c)** Fit y ~ x1 + x2; describe. How do beta-hat's compare to true betas? Reject H0: beta_1 = 0? H0: beta_2 = 0?
# **(d)** Fit y ~ x1 only; reject H0: beta_1 = 0?
# **(e)** Fit y ~ x2 only; reject H0 that its coefficient is 0?
# **(f)** Do (c)-(e) contradict each other? Explain.
# **(g)** Add the mismeasured point below and refit (c)-(e). Effect on each model? Is it an outlier, high-leverage, or both?

# %%
# (a)
rng = np.random.default_rng(10)
x1 = rng.uniform(0, 1, size=100)
x2 = 0.5 * x1 + rng.normal(size=100) / 10
y = 2 + 2 * x1 + 0.3 * x2 + rng.normal(size=100)

# %%
# (b)

# %%
# (c)

# %%
# (d)

# %%
# (e)

# %%
# (f)

# %%
# (g)
x1 = np.concatenate([x1, [0.1]])
x2 = np.concatenate([x2, [0.8]])
y = np.concatenate([y, [6]])

# %% [markdown]
# ### Exercise 15 — Boston — predicting crime rate
#
# Predict per-capita crime rate from the other `Boston` variables.
#
# **(a)** Simple regression of the response on each predictor separately; which are significant? Add plots.
# **(b)** Multiple regression on all predictors; for which can you reject H0: beta_j = 0?
# **(c)** Compare (a) vs (b): plot univariate coefficients (x-axis) against multiple-regression coefficients (y-axis), one point per predictor.
# **(d)** Evidence of non-linearity? For each predictor X, fit Y ~ X + X^2 + X^3.

# %%
# (a)

# %%
# (b)

# %%
# (c)

# %%
# (d)
